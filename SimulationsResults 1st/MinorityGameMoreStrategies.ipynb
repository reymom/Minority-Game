# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
from mygame_functions import GameSimulationSPriv

# %%
Ns = 81
Np = 71
M = 7
numponderas = 300
imprimecada = 30
used_strategies = []
gain_priv = []
esesprimas = []
SP = 1
rango_s = 26
for eses in range(rango_s):
    if eses < 10:
        SP += 1
    else:
        SP += 2
    esesprimas.append(SP)
    print("        ----------------------")
    print("        S' = {}        ({}/{})".format(SP, eses + 1, rango_s))
    print("        ----------------------")
    g = 0
    us = 0
    for i in range(numponderas):
        gain, numstrats = GameSimulationSPriv(Ns, Np, M, SP, T=10000)
        g += np.mean(gain)
        us += numstrats
        if (i + 1) % imprimecada == 0:
            print('      ---> Ponderacion nº {}/{}'.format(i + 1, numponderas))
            print("      S' = {}        ({}/{})".format(SP, eses + 1, rango_s))
            print('            <gain> = {}'.format(g / (i + 1)))
            print('          <s_used> = {}'.format(us / (i + 1)))
            print(' ')
    
    gain_priv.append(g / numponderas)
    used_strategies.append(us / numponderas)
    print('Remembering')
    print("S'              = ", esesprimas)
    print('Gs              = ', gain_priv)
    print('Used strategies = ', used_strategies)

# %%
file_name = "PriviS_Sused_gainVIRTUALbien_" + str(Ns) + "Nspecs_" + str(
    Np) + 'Nprods_' + str(M) + 'm_' + str(numponderas) + "numponderas"
with open('{}.dat'.format(file_name), 'w') as file:
    for i in range(len(esesprimas)):
        file.write('{} {} {}\n'.format(esesprimas[i], used_strategies[i],
                                       gain_priv[i]))

# %%
Ns = 61
Np = 101
M = 5
numponderas = 300
file_name = "PriviS_Sused_gain_" + str(Ns) + "Nspecs_" + str(
    Np) + 'Nprods_' + str(M) + 'm_' + str(numponderas) + "numponderas"
esesprimas1 = []
used_strat1 = []
gain_privi1 = []
with open('{}.dat'.format(file_name), 'r') as file:
    for line in file:
        value = line.split()
        value[2].split('\n')
        esesprimas1.append(float(value[0]))
        used_strat1.append(float(value[1]))
        gain_privi1.append(float(value[2]))

# %%
Ns = 81
Np = 71
M = 7
numponderas = 400
file_name = "PriviS_Sused_gain_" + str(Ns) + "Nspecs_" + str(
    Np) + 'Nprods_' + str(M) + 'm_' + str(numponderas) + "numponderas"
esesprimas0 = []
used_strat0 = []
gain_privi0 = []
with open('{}.dat'.format(file_name), 'r') as file:
    for line in file:
        value = line.split()
        value[2].split('\n')
        esesprimas0.append(float(value[0]))
        used_strat0.append(float(value[1]))
        gain_privi0.append(float(value[2]))

# %%
Ns = 81
Np = 71
M = 7
numponderas = 300
file_name = "PriviS_Sused_gainVIRTUAL_" + str(Ns) + "Nspecs_" + str(
    Np) + 'Nprods_' + str(M) + 'm_' + str(numponderas) + "numponderas"
esesprimas0v = []
used_strat0v = []
gain_privi0v = []
with open('{}.dat'.format(file_name), 'r') as file:
    for line in file:
        value = line.split()
        value[2].split('\n')
        esesprimas0v.append(float(value[0]))
        used_strat0v.append(float(value[1]))
        gain_privi0v.append(float(value[2]))

# %%
Ns = 101
Np = 51
M = 8
numponderas = 320
file_name = "PriviS_Sused_gain_" + str(Ns) + "Nspecs_" + str(
    Np) + 'Nprods_' + str(M) + 'm_' + str(numponderas) + "numponderas"
esesprimas2 = []
used_strat2 = []
gain_privi2 = []
with open('{}.dat'.format(file_name), 'r') as file:
    for line in file:
        value = line.split()
        value[2].split('\n')
        esesprimas2.append(float(value[0]))
        used_strat2.append(float(value[1]))
        gain_privi2.append(float(value[2]))

# %%
fig, ax = plt.subplots(2, sharex=True,gridspec_kw={'hspace': 0},figsize=(10, 8))
#ax[0].set_facecolor('xkcd:eggshell')

ax[0].set(xscale='log')
ax[0].set_ylabel("<Nº strategies used>", fontsize='large')

ax[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: ('{{:.{:1d}f}}'.format(
                                                        int(np.maximum(-np.log10(x), 0)))).format(x)))
ax[0].tick_params(which='both', length=5, width = 2, direction = 'inout', 
                  labelbottom=True, labeltop=False, labelleft=True, labelright=False,
                  bottom=True, top=True, left=True, right=True)

lin1, = ax[0].plot(esesprimas0, used_strat0, lw=1.5, ls = '-', color = 'k', alpha=.6)
mark1, = ax[0].plot(esesprimas0, used_strat0, ls = '', marker='o', ms = 6, alpha=.8, mec='crimson', mfc='crimson')

lin2, = ax[0].plot(esesprimas1, used_strat1, lw=1.5, ls = '-', color = 'k', alpha=.6)
mark2, = ax[0].plot(esesprimas1, used_strat1, ls = '', marker='s', ms = 6, alpha=.8, mec='darkcyan', mfc='darkcyan')

lin3, = ax[0].plot(esesprimas2, used_strat2, lw=1.5, ls = '-', color = 'k', alpha=.6)
mark3, = ax[0].plot(esesprimas2, used_strat2, ls = '', marker='D', ms = 6, alpha=.8, mec='indigo', mfc='indigo')

labels = ['H/N = 1.3', 'H/N = 0.6', 'H/N = 0.3']
ax[0].legend([(lin2, mark2), (lin1, mark1), (lin3, mark3)], labels, loc=0)

#ax[0].set_yticks([2, 2.5, 3, 3.5, 4])
#ax[0].set_yticklabels(['2', '2.5', '3', '3.5', '4'])

ax[1].set(xscale='log')
ax[1].set_xlabel("S'", fontsize='large') 
ax[1].set_ylabel(r"$G_{S'}$", fontsize='large')
ax[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: ('{{:.{:1d}f}}'.format(
                                                        int(np.maximum(-np.log10(x), 0)))).format(x)))
ax[1].tick_params(which='both', length=5, width = 2, direction='inout', 
                  labelbottom=True, labeltop=False, labelleft=True, labelright=False,
                  bottom=True, top=True, left=True, right=True)
lin1, = ax[1].plot(esesprimas0, gain_privi0, lw = 1.5, ls = '-', color='k', alpha=.6)
mark1, = ax[1].plot(esesprimas0, gain_privi0, ls=' ', marker='o', ms=6, alpha =.8, mec='crimson', mfc='crimson')

lin2, = ax[1].plot(esesprimas1, gain_privi1, lw = 1.5, ls = '-', color='k', alpha=.6)
mark2, = ax[1].plot(esesprimas1, gain_privi1, ls=' ', marker='s', ms=6, alpha =.8, mec='darkcyan', mfc='darkcyan')

lin3, = ax[1].plot(esesprimas2, gain_privi2, lw = 1.5, ls = '-', color='k', alpha=.6)
mark3, = ax[1].plot(esesprimas2, gain_privi2, ls=' ', marker='D', ms=6, alpha =.8, mec='indigo', mfc='indigo')

ax[1].axhline(y=0, color='k', alpha=0.7, linestyle='--')
ax[1].set_yticks([-0.5, 0, 0.5, 1, 1.5])
ax[1].set_yticklabels(['-0.5','0', '0.5', '1', '1.5'])

filename = "Spused_GainSprimavsSPrima_5,7,8M_61,81,101Ns_101,71,51Np_300,400,320ponds.png"
fig.savefig(filename, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
#ax[0].set_facecolor('xkcd:eggshell')

ax.set(xscale='log')
ax.set_xlabel("S'", fontsize='large') 
ax.set_ylabel(r"$G_{S'}$", fontsize='large')

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: ('{{:.{:1d}f}}'.format(
                                                        int(np.maximum(-np.log10(x), 0)))).format(x)))
ax.tick_params(which='both', length=5, width = 2, direction = 'inout', 
                  labelbottom=True, labeltop=False, labelleft=True, labelright=False,
                  bottom=True, top=True, left=True, right=True)

lin1, = ax.plot(esesprimas0, gain_privi0, lw=1.5, ls = '-', color = 'k', alpha=.6)
mark1, = ax.plot(esesprimas0, gain_privi0, ls = '', marker='o', ms = 6, alpha=.8, mec='crimson', mfc='crimson')

lin0v, = ax.plot(esesprimas0v, gain_privi0v, lw=1.5, ls = '--', color = 'k', alpha=.6)
mark0v, = ax.plot(esesprimas0v, gain_privi0v, ls = '', marker='o', 
                     ms = 6, alpha=.8, mec='lightsalmon', mfc='lightsalmon')

ax.axhline(y=0, color='k', alpha=0.7, linestyle='--')

ax.set_yticks([-0.5, 0, 0.5, 1, 1.5])
ax.set_yticklabels(['-0.5','0', '0.5', '1', '1.5'])

labels = ['Real Gain', 'Virtual gain']
ax.legend([(lin1, mark1), (lin0v, mark0v)], labels, loc=0)

filename = "REAL_VIRTUALGainSprimavsSP_7M_81Ns_71Np_300,400ponds.png"
fig.savefig(filename, bbox_inches='tight')
