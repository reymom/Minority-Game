# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import MultipleLocator
from MinorityGameComplex import GameSimulationImitationTermalGraphs

# %%
S=2
N=401
T=5000
dynT=1
numponderas = 10
imprimecada = 1

net=0 #RANDOM NETWORK
grado=10
p=None

lenemes = 8
emes = np.arange(5,5+lenemes)
alpha=2**emes/N

lenimis = 5
#nimis = np.array([1,100,200,300,400])
lenimis = 1
nimis = np.array([400])

sigma = np.zeros((lenimis, lenemes))
gains = np.zeros((lenimis, lenemes))
gains_imitators = np.zeros((lenimis, lenemes))

for m in range(lenemes):
    M = emes[m]
    for ncop in range(lenimis):
        Ncop = nimis[ncop]
        print(' ..............................')
        print('              M = {}     ({} / {})'.format(M, m+1, lenemes))
        print('           Ncop = {}     ({} / {})'.format(Ncop, ncop+1, lenimis))
        print(' ..............................')
        s = 0
        g = 0
        gc = 0
        for pond in range(numponderas):
            A, G, GC = GameSimulationImitationTermalGraphs(S, M, N, Ncop, T, dynT, net, grado, p)
            s += np.var(A) / N
            g += np.mean(G)
            gc += np.mean(GC)
            if (pond + 1) % imprimecada == 0:
                print('        -Ponderacion nº {}/{}'.format(pond + 1, numponderas))
                print('             σ²/N = {}'.format(s / (pond + 1)))
                print('             <g>  = {}'.format(g / (pond + 1)))
                print('             <gi> = {}'.format(gc / (pond + 1)))
        sigma[ncop,m] =  s / numponderas
        gains[ncop,m] = g / numponderas
        gains_imitators[ncop,m] = gc / numponderas
        print('...Remembering...')
        print('Ncops = ', nimis[:(ncop+1)])
        print('σ²/N = ', sigma[:(ncop+1),m])
        print(' <g> = ', gains[:(ncop+1),m])
        print('<gi> = ', gains_imitators[:(ncop+1),m])
# Out:
#  ..............................
#               M = 5     (1 / 8)
#            Ncop = 400     (1 / 1)
#  ..............................
#         -Ponderacion nº 1/10
#              σ²/N = 375.7988019008478
#              <g>  = -17.6284
#              <gi> = -379.043949
#         -Ponderacion nº 2/10
#              σ²/N = 375.5852735577057
#              <g>  = -35.650400000000005
#              <gi> = -387.12925199999995
#         -Ponderacion nº 3/10
#              σ²/N = 364.93337663946795
#              <g>  = -27.09386666666667
#              <gi> = -389.18571599999996
#         -Ponderacion nº 4/10
#              σ²/N = 369.25781070443884
#              <g>  = -27.779000000000003
#              <gi> = -390.94471649999997
#         -Ponderacion nº 5/10
#              σ²/N = 366.97867066030915
#              <g>  = -30.3228
#              <gi> = -391.6705666
#         -Ponderacion nº 6/10
#              σ²/N = 370.2632972256691
#              <g>  = -25.9826
#              <gi> = -391.0301468333333
#         -Ponderacion nº 7/10
#              σ²/N = 372.24769454255784
#              <g>  = -22.959142857142858
#              <gi> = -391.2799318571428
#         -Ponderacion nº 8/10
#              σ²/N = 373.7954907097755
#              <g>  = -24.6857
#              <gi> = -390.72375324999996
#         -Ponderacion nº 9/10
#              σ²/N = 371.96891928733714
#              <g>  = -35.69813333333334
#              <gi> = -391.29501955555554
#         -Ponderacion nº 10/10
#              σ²/N = 374.107335512379
#              <g>  = -37.412760000000006
#              <gi> = -391.5865657
# ...Remembering...
# Ncops =  [400]
# σ²/N =  [374.10733551]
#  <g> =  [-37.41276]
# <gi> =  [-391.5865657]
#  ..............................
#               M = 6     (2 / 8)
#            Ncop = 400     (1 / 1)
#  ..............................
#         -Ponderacion nº 1/10
#              σ²/N = 389.96532588488776
#              <g>  = -7.1204
#              <gi> = -391.932423
#         -Ponderacion nº 2/10
#              σ²/N = 390.6916759100249
#              <g>  = -45.949200000000005
#              <gi> = -392.531889
#         -Ponderacion nº 3/10
#              σ²/N = 390.5227887095594
#              <g>  = -34.516400000000004
#              <gi> = -392.4659303333333
#         -Ponderacion nº 4/10
#              σ²/N = 389.19312095860346
#              <g>  = -41.7028
#              <gi> = -393.482575
#         -Ponderacion nº 5/10
#              σ²/N = 388.5360165921995
#              <g>  = -33.820640000000004
#              <gi> = -392.2696964
#         -Ponderacion nº 6/10
#              σ²/N = 389.3265567515877
#              <g>  = -32.9534
#              <gi> = -392.88815716666664
#         -Ponderacion nº 7/10
#              σ²/N = 388.9353195939865
#              <g>  = -35.03565714285715
#              <gi> = -392.2554897142857
#         -Ponderacion nº 8/10
#              σ²/N = 389.481318513616
#              <g>  = -51.741600000000005
#              <gi> = -392.565132
#         -Ponderacion nº 9/10
#              σ²/N = 388.6541762797008
#              <g>  = -58.65728888888889
#              <gi> = -391.8852523333333
#         -Ponderacion nº 10/10
#              σ²/N = 388.6361368652369
#              <g>  = -58.86052000000001
#              <gi> = -391.7639635
# ...Remembering...
# Ncops =  [400]
# σ²/N =  [388.63613687]
#  <g> =  [-58.86052]
# <gi> =  [-391.7639635]
#  ..............................
#               M = 7     (3 / 8)
#            Ncop = 400     (1 / 1)
#  ..............................
#         -Ponderacion nº 1/10
#              σ²/N = 386.46112469825437
#              <g>  = -45.4864
#              <gi> = -389.247608
#         -Ponderacion nº 2/10
#              σ²/N = 387.5514693129177
#              <g>  = -59.138200000000005
#              <gi> = -389.8920785
#         -Ponderacion nº 3/10
#              σ²/N = 389.56701148129673
#              <g>  = -48.9772
#              <gi> = -391.93691966666665
#         -Ponderacion nº 4/10
#              σ²/N = 390.04751335451374
#              <g>  = -46.1554
#              <gi> = -392.0469605
#         -Ponderacion nº 5/10
#              σ²/N = 389.0327155035611
#              <g>  = -45.15072
#              <gi> = -392.1931552
#         -Ponderacion nº 6/10
#              σ²/N = 389.4583947966085
#              <g>  = -40.6156
#              <gi> = -392.64181633333334
#         -Ponderacion nº 7/10
#              σ²/N = 388.1364955456502
#              <g>  = -39.01114285714285
#              <gi> = -392.3667492857143
#         -Ponderacion nº 8/10
#              σ²/N = 387.7983755276309
#              <g>  = -37.595099999999995
#              <gi> = -392.52803125
#         -Ponderacion nº 9/10
#              σ²/N = 387.8888892648379
#              <g>  = -38.343333333333334
#              <gi> = -392.65294077777776
#         -Ponderacion nº 10/10
#              σ²/N = 387.3045606016559
#              <g>  = -38.153
#              <gi> = -392.5882219
# ...Remembering...
# Ncops =  [400]
# σ²/N =  [387.3045606]
#  <g> =  [-38.153]
# <gi> =  [-392.5882219]
#  ..............................
#               M = 8     (4 / 8)
#            Ncop = 400     (1 / 1)
#  ..............................
#         -Ponderacion nº 1/10
#              σ²/N = 391.0624630998504
#              <g>  = -31.918
#              <gi> = -392.28943300000003
#         -Ponderacion nº 2/10
#              σ²/N = 391.75169504538655
#              <g>  = -23.452199999999998
#              <gi> = -392.8836755
#         -Ponderacion nº 3/10
#              σ²/N = 390.3903100668329
#              <g>  = -17.49053333333333
#              <gi> = -391.5418536666666
#         -Ponderacion nº 4/10
#              σ²/N = 390.94996490882795
#              <g>  = -25.8493
#              <gi> = -392.03128574999994
#         -Ponderacion nº 5/10
#              σ²/N = 391.1317862555611
#              <g>  = -25.63864
#              <gi> = -392.24415619999996
#         -Ponderacion nº 6/10
#              σ²/N = 390.80448270251037
#              <g>  = -30.297933333333333
#              <gi> = -392.39785249999994
#         -Ponderacion nº 7/10
#              σ²/N = 390.4316322427075
#              <g>  = -37.4708
#              <gi> = -392.2421961428571
#         -Ponderacion nº 8/10
#              σ²/N = 389.89985560309225
#              <g>  = -34.50045
#              <gi> = -391.6665763749999
#         -Ponderacion nº 9/10
#              σ²/N = 389.68293934133555
#              <g>  = -35.07608888888889
#              <gi> = -391.7429599999999
#         -Ponderacion nº 10/10
#              σ²/N = 388.41248644137653
#              <g>  = -32.2524
#              <gi> = -390.6198042
# ...Remembering...
# Ncops =  [400]
# σ²/N =  [388.41248644]
#  <g> =  [-32.2524]
# <gi> =  [-390.6198042]
#  ..............................
#               M = 9     (5 / 8)
#            Ncop = 400     (1 / 1)
#  ..............................
#         -Ponderacion nº 1/10
#              σ²/N = 384.79357787890274
#              <g>  = -11.996
#              <gi> = -386.82719
#         -Ponderacion nº 2/10
#              σ²/N = 388.8340235481296
#              <g>  = -9.8202
#              <gi> = -390.7688815
#         -Ponderacion nº 3/10
#              σ²/N = 389.4967354997838
#              <g>  = -7.3852
#              <gi> = -391.5920556666667
#         -Ponderacion nº 4/10
#              σ²/N = 390.3571548144638
#              <g>  = -38.4109
#              <gi> = -392.45846374999996
#         -Ponderacion nº 5/10
#              σ²/N = 389.8076019064339
#              <g>  = -31.5452
#              <gi> = -391.82069379999996
#         -Ponderacion nº 6/10
#              σ²/N = 389.7147281548794
#              <g>  = -26.92533333333333
#              <gi> = -391.554002
#         -Ponderacion nº 7/10
#              σ²/N = 389.9583296517563
#              <g>  = -24.600914285714286
#              <gi> = -391.70486114285717
#         -Ponderacion nº 8/10
#              σ²/N = 390.365064065187
#              <g>  = -22.65195
#              <gi> = -392.03165762500004
#         -Ponderacion nº 9/10
#              σ²/N = 390.26065214967025
#              <g>  = -24.877466666666667
#              <gi> = -391.8835681111111
#         -Ponderacion nº 10/10
#              σ²/N = 390.4183245985038
#              <g>  = -31.4966
#              <gi> = -391.96029250000004
# ...Remembering...
# Ncops =  [400]
# σ²/N =  [390.4183246]
#  <g> =  [-31.4966]
# <gi> =  [-391.9602925]
#  ..............................
#               M = 10     (6 / 8)
#            Ncop = 400     (1 / 1)
#  ..............................
#         -Ponderacion nº 1/10
#              σ²/N = 391.66423716349135
#              <g>  = -10.5024
#              <gi> = -392.640264
#         -Ponderacion nº 2/10
#              σ²/N = 391.84968047202
#              <g>  = -8.8734
#              <gi> = -392.8188285
#         -Ponderacion nº 3/10
#              σ²/N = 392.2198411791854
#              <g>  = -6.876266666666667
#              <gi> = -393.193192
#         -Ponderacion nº 4/10
#              σ²/N = 391.51475296418954
#              <g>  = -21.967
#              <gi> = -392.4475755
#         -Ponderacion nº 5/10
#              σ²/N = 391.5313902010574
#              <g>  = -24.7576
#              <gi> = -392.5915924
#         -Ponderacion nº 6/10
#              σ²/N = 391.3261508629094
#              <g>  = -23.18726666666667
#              <gi> = -392.37298250000003
#         -Ponderacion nº 7/10
#              σ²/N = 390.7874589529035
#              <g>  = -28.084685714285715
#              <gi> = -391.818786
#         -Ponderacion nº 8/10
#              σ²/N = 390.6191290675312
#              <g>  = -24.845950000000002
#              <gi> = -391.642848625
#         -Ponderacion nº 9/10
#              σ²/N = 390.41488210934887
#              <g>  = -23.97426666666667
#              <gi> = -391.4290821111111
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1dac9005f0d1> in <module>
#      35         gc = 0
#      36         for pond in range(numponderas):
# ---> 37             A, G, GC = GameSimulationImitationTermalGraphs(S, M, N, Ncop, T, dynT, net, grado, p)
#      38             s += np.var(A) / N
#      39             g += np.mean(G)
#
# ~/Documentos/Minority_Game/Minority-Game/SimulationsResults 2on/MinorityGameComplex.py in GameSimulationImitationTermalGraphs(S, M, N, Ncop, T, dynT, net, grado, p)
#     575
#     576         A, scores, gains = GameStepImitationTermalGraphs(S, M, N, Ncop, t, counts, neighs,
# --> 577                                         nodes, imitators_now, strategies, scores)
#     578         A_t[t] = A
#     579         G_t[t] = np.mean(gains[nodes])
#
# ~/Documentos/Minority_Game/Minority-Game/SimulationsResults 2on/MinorityGameComplex.py in GameStepImitationTermalGraphs(S, M, N, Ncop, t, counts, neighs, nodes, imitators_now, strategies, scores)
#     530     if len(imitators_now) > 0:
#     531         strategies, scores = ImitationMaximum(strategies, scores, S,
# --> 532                                                 imitators_now, counts, neighs)
#     533
#     534     #DYNAMICS OF MINORITY GAME
#
# ~/Documentos/Minority_Game/Minority-Game/SimulationsResults 2on/MinorityGameComplex.py in ImitationMaximum(strategies, scores, S, imitators_now, counts, neighs)
#     510         maximoneigh = np.amax(scores[neighs[counts[node]:counts[node+1]]].flatten())
#     511         iguales = np.argwhere(
# --> 512             scores[neighs[counts[node]:counts[node+1]]].flatten() == maximoneigh).flatten()
#     513         cual = np.random.choice(iguales)
#     514         strat = cual%S
#
# ~/.local/share/virtualenvs/Documentos-R9YD94Vv/lib/python3.5/site-packages/numpy/core/numeric.py in argwhere(a)
#     879
#     880     """
# --> 881     return transpose(nonzero(a))
#     882
#     883
#
# ~/.local/share/virtualenvs/Documentos-R9YD94Vv/lib/python3.5/site-packages/numpy/core/fromnumeric.py in nonzero(a)
#    1776
#    1777     """
# -> 1778     return _wrapfunc(a, 'nonzero')
#    1779
#    1780
#
# KeyboardInterrupt:

# %%
for nc in range(len(nimis)):
    file_name = 'Sigma,GainImitator,GainALLvsALPHA_' + str(N) +' N_' + str(
                                nimis[nc])+'Ncop_Rand_' + str(grado) + '<k>' +str(dynT) + 'dynT_' +  str(
                                T)+'T_'+str(numponderas)+'numponds'
    with open('{}.dat'.format(file_name), 'w') as file:
        for i in range(len(alpha)):
            file.write('{} {} {} {}\n'.format(alpha[i], sigma[nc,i], gains[nc,i], gains_imitators[nc,i]))

# %%
N=401
T=10000
dynT=1000
numponderas = 100
grado=30
lenemes = 8
lenimis = 5
nimis = np.array([1,100,200,300,400])

alpha0 = np.zeros((lenemes))
sigma0 = np.zeros((lenimis, lenemes))
gains0 = np.zeros((lenimis, lenemes))
gains_imitators0 = np.zeros((lenimis, lenemes))

for nc in range(len(nimis)):
    file_name = 'Sigma,GainImitator,GainALLvsALPHA_' + str(N) +' N_' + str(
                                nimis[nc])+'Ncop_Rand_' + str(grado) + '<k>' +str(dynT) + 'dynT_' +  str(
                                T)+'T_'+str(numponderas)+'numponds'
    with open('{}.dat'.format(file_name), 'r') as file:
        i = 0
        for line in file:
            value = line.split()
            value[3].split('\n')
            if nc == 0:
                alpha0[i] = float(value[0])
            sigma0[nc, i] = float(value[1])
            gains0[nc, i] = float(value[2])
            gains_imitators0[nc, i] = float(value[3])
            i += 1

# %%
fig, ax = plt.subplots(1, figsize=(8,6))
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$\alpha$', fontsize='large')
ax.set_ylabel(r'$\sigma^2/N$', fontsize='large')

ax.tick_params(which='minor', direction = 'inout', length=3, width=1,
              labelbottom=False, labeltop=False, labelleft=False, labelright=False,
                  bottom=True, top=True, left=True, right=True)

ax.tick_params(which='major', direction = 'inout', length=6, width = 2,
                  labelbottom=True, labeltop=False, labelleft=True, labelright=False,
                  bottom=True, top=True, left=True, right=True)

cols = ['k', 'dodgerblue', 'yellow', 'crimson', 'forestgreen']

lin = ['1','2','3','4','5']
mark = ['1','2','3','4','5']
for i in range(len(nimis)):
    nc=i
    lin[nc], = ax.plot(alpha0, sigma0[nc], lw=0.5, ls = '--', color = 'k', alpha=0.5)
    mark[nc], = ax.plot(alpha0, sigma0[nc], ls = '', marker = 'o', mec='k',mfc=cols[nc],
                     ms = 7, mew = 1, alpha=0.9)



lin[0], = ax.plot(alpha0, sigma0[0], lw=1, ls = '-', color = 'k', alpha=0.8)
mark[0], = ax.plot(alpha0, sigma0[0], ls = '', marker = 'o', mec='k',mfc=cols[0],
                 ms = 7, mew = 1, alpha=0.9)
    
yticks1 = [1]
ax.set_yticks(yticks1)
ax.set_yticklabels([str(i) for i in yticks1])

xticks1 = [0.1, 1, 10]
ax.set_xticks(xticks1)
ax.set_xticklabels([str(i) for i in xticks1])

ax.axhline(y=1, xmin=0, xmax=1, color='k', alpha=0.7, linestyle='--')

labels = [(r'$N_I = $ ' + str(nimis[i])) for i in range(len(nimis))]
ax.legend([(lin[i], mark[i]) for i in range(len(lin))], 
          labels, loc='upper center', bbox_to_anchor=[0.4,1])

filename = 'contodoRANDOM<K>30_SIGMAvsALPHA' + str(
                    N) +'N_' + 'Ncop_CG_' + str(
                    dynT) + 'dynT_' + str(T)+'T_'+str(numponderas)+'numponds.png'
fig.savefig(filename, bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, 2, figsize=(14,6))
fig.subplots_adjust(wspace=0.13)

cols = ['k', 'dodgerblue', 'yellow', 'crimson', 'forestgreen']
labels = [(r'$N_I = $ ' + str(i)) for i in nimis]
i = -1
for nc in [1,4]:#range(len(nimis)):
    i += 1
    ax[i].tick_params(which='both', direction='inout', labelbottom=True, 
                   labeltop=False, labelleft=True, labelright=False,
                   bottom=True, top=True, left=True, right=True)
    ax[i].yaxis.set_major_locator(MultipleLocator(1))
    ax[i].yaxis.set_minor_locator(MultipleLocator(0.5))
    
    ax[i].set_xscale('log')
    ax[i].set_xlabel(r'$\alpha$', fontsize='large')
    ax[i].set_title(r'$N_I = $ ' + str(nimis[nc]))
    #ax[i].set_ylim([-8,0.8])
    ax[i].plot(alpha, gains[nc], lw=.8, ls = '-', color = 'k', alpha=0.8,
             marker='o', mec = 'k', mfc=cols[nc], mew = 1, ms = 7, label=r'$G_{NORMAL}$')
    ax[i].plot(alpha, gains_imitators[nc], lw=.8, ls = '-', color = 'k', alpha=0.8,
             marker='s', mec = 'k', mfc=cols[nc], mew = 1, ms = 7, label=r'$G_{IMITATORS}$')
    
    ax[i].axhline(y=-1, xmin=0, xmax=1, color='k', alpha=0.7, linestyle='--')
    xticks1 = [0.1, 1, 10]
    ax[i].set_xticks(xticks1)
    ax[i].set_xticklabels([str(i) for i in xticks1])

ax[0].tick_params(which='both', direction='inout', labelbottom=True, 
                   labeltop=False, labelleft=True, labelright=False,
                   bottom=True, top=True, left=True, right=True)
ax[0].set_ylabel(r'$G_i$', fontsize='large')

"""yticks1 = [0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4]
ax.set_yticks(yticks1)
ax.set_yticklabels([str(i) for i in yticks1])"""

ax[0].legend(loc='lower right')
ax[1].legend(loc='lower left')


filename = 'Rand<k>30_GAINSvsALPHA' + str(
                    N) +'N_' + 'Ncop_CG_' + str(
                    dynT) + 'dynT_' + str(T)+'T_'+str(numponderas)+'numponds.png'
fig.savefig(filename, bbox_inches='tight')
