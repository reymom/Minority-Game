# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from MinorityGameComplex import GameSimulationImitationCG

# %%
S=2
N=201
Ncop=1
T=20000
numponderas = 200
imprimecada = 10
emes = np.array([4])

lendyn = 13
leneme = 3
"""sigma = np.zeros((leneme,lendyn))
gains = np.zeros((leneme,lendyn))
gains_imitators = np.zeros((leneme,lendyn))"""

dynamic_times = np.logspace(0,4.3,lendyn).astype(int)

for m in range(len(emes)):
    M = emes[m]
    for dynt in range(1):#len(dynamic_times)):
        #dynT = dynamic_times[dynt]
        dynT = 735
        print(' ..............................')
        print('              M = {}     ({} / {})'.format(M, m+1, leneme))
        print('   Dynamic time = {}     ({} / {})'.format(dynT, dynt+1, lendyn))
        print(' ..............................')
        s = 0
        g = 0
        gc = 0
        for pond in range(numponderas):
            A, G, GC = GameSimulationImitationCG(S, M, N, Ncop, p, T, dynT)
            s += np.var(A) / N
            g += np.mean(G)
            gc += np.mean(GC)
            if (pond + 1) % imprimecada == 0:
                print('        -Ponderacion nº {}/{}'.format(pond + 1, numponderas))
                print('             σ²/N = {}'.format(s / (pond + 1)))
                print('             <g>  = {}'.format(g / (pond + 1)))
                print('             <gi> = {}'.format(gc / (pond + 1)))
        """sigma[m,dynt] =  s / numponderas
        gains[m,dynt] = g / numponderas
        gains_imitators[m,dynt] = gc / numponderas"""
        print('Remembering...')
        print('dynt = ', dynamic_times[:(dynt+1)])
        print('σ²/N = ', sigma[m,:(dynt+1)])
        print(' <g> = ', gains[m,:(dynt+1)])
        print('<gi> = ', gains_imitators[m,:(dynt+1)])
# Out:
#  ..............................
#               M = 4     (1 / 3)
#    Dynamic time = 735     (1 / 13)
#  ..............................
#         -Ponderacion nº 10/200
#              σ²/N = 4.027829611049752
#              <g>  = -4.03888985
#              <gi> = -1.8157899999999998
#         -Ponderacion nº 20/200
#              σ²/N = 4.073801947405473
#              <g>  = -4.082390275000001
#              <gi> = -2.356145
#         -Ponderacion nº 30/200
#              σ²/N = 4.092854675726368
#              <g>  = -4.1011563
#              <gi> = -2.4325400000000004
#         -Ponderacion nº 40/200
#              σ²/N = 4.075207757452736
#              <g>  = -4.0833851625
#              <gi> = -2.4397374999999997
#         -Ponderacion nº 50/200
#              σ²/N = 4.053844766839801
#              <g>  = -4.062107890000001
#              <gi> = -2.40123
#         -Ponderacion nº 60/200
#              σ²/N = 4.005329270940298
#              <g>  = -4.0130385166666676
# ...

# %%
#file_name0 = 'MAXIMITATION_Sigma,GainImitator,GainALLvsDyntimes_4M201N_CG,1p_20000T_100numponds'
#file_name1 = 'MAXIMITATION_Sigma,GainImitator,GainALLvsDyntimes_6M201N_CG,1p_20000T_100numponds'
#file_name2 = 'MAXIMITATION_Sigma,GainImitator,GainALLvsDyntimes_9M201N_CG,1p_20000T_100numponds'
#with open('{}.dat'.format(file_name2), 'w') as file:
    for i in range(len(dynamic_times)):
        file.write('{} {} {} {}\n'.format(dynamic_times[i], sigma[2,i], gains[2,i], gains_imitators[2,i]))

# %%
dynamic_times0 = []
sigma0 = []
gains0 = []
gains_imitators0 = []
file_name = 'MAXIMITATION_Sigma,GainImitator,GainALLvsDyntimes_4M201N_CG,1p_20000T_100numponds'
with open('{}.dat'.format(file_name), 'r') as file:
    for line in file:
        value = line.split()
        value[3].split('\n')
        dynamic_times0.append(float(value[0]))
        sigma0.append(float(value[1]))
        gains0.append(float(value[2]))
        gains_imitators0.append(float(value[3]))

# %%
dynamic_times1 = []
sigma1 = []
gains1 = []
gains_imitators1 = []

file_name = 'MAXIMITATION_Sigma,GainImitator,GainALLvsDyntimes_6M201N_CG,1p_20000T_100numponds'
with open('{}.dat'.format(file_name), 'r') as file:
    for line in file:
        value = line.split()
        value[3].split('\n')      
        dynamic_times1.append(float(value[0]))
        sigma1.append(float(value[1]))
        gains1.append(float(value[2]))
        gains_imitators1.append(float(value[3]))

# %%
dynamic_times2 = []
sigma2 = []
gains2 = []
gains_imitators2 = []

file_name = 'MAXIMITATION_Sigma,GainImitator,GainALLvsDyntimes_9M201N_CG,1p_20000T_100numponds'
with open('{}.dat'.format(file_name), 'r') as file:
    for line in file:
        value = line.split()
        value[3].split('\n')        
        dynamic_times2.append(float(value[0]))
        sigma2.append(float(value[1]))
        gains2.append(float(value[2]))
        gains_imitators2.append(float(value[3]))

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.set(title = 'Complete Graph', xscale='log', ylim=[0.12,2.15])

ax.set_xlabel(r'$\tau_{I}/\tau_{MG}$', fontsize='large')
ax.set_ylabel(r'$G_{MG}/G_{I}$', fontsize='large')

ax.tick_params(which='both', direction='inout', labelbottom=True, labeltop=False, labelleft=True, labelright=False,
               bottom=True, top=True, left=True, right=True)


c0 = 'dodgerblue'
lin0, = ax.plot(dynamic_times0[:-1], np.array(gains0)[:-1]/np.array(gains_imitators0)[:-1], 
               lw=.8, ls = '-', color = 'k', alpha=1)
mark0, = ax.plot(dynamic_times0[:-1], np.array(gains0)[:-1]/np.array(gains_imitators0)[:-1],
                ls = '', marker='o', mec = c0, mfc=c0, mew = 1, ms = 7, alpha=.9)

c1 = 'yellowgreen'
lin1, = ax.plot(dynamic_times1[:-1], np.array(gains1)[:-1]/np.array(gains_imitators1)[:-1], 
               lw=.8, ls = '-', color = 'k', alpha=1)
mark1, = ax.plot(dynamic_times1[:-1], np.array(gains1)[:-1]/np.array(gains_imitators1)[:-1],
                ls = '', marker='s', mec = c1, mfc=c1, mew = 1, ms = 6, alpha=.9)

c2 = 'crimson'
lin2, = ax.plot(dynamic_times2[:-1], np.array(gains2)[:-1]/np.array(gains_imitators2)[:-1], 
               lw=.8, ls = '-', color = 'k', alpha=1)
mark2, = ax.plot(dynamic_times2[:-1], np.array(gains2)[:-1]/np.array(gains_imitators2)[:-1],
                ls = '', marker='D', mec = c2, mfc=c2, mew = 1, ms = 5, alpha=.9)


labels = [r'$\alpha = 0.08$', r'$\alpha = 0.32$', r'$\alpha = 2.55$']
ax.legend([(lin0, mark0), (lin1, mark1), (lin2, mark2)], labels, loc=0)


yticks1 = [0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]
ax.set_yticks(yticks1)
ax.set_yticklabels([str(i) for i in yticks1])

ax.axhline(y=1, xmin=0, xmax=1, color='k', alpha=0.7, linestyle='--')

filename = "Gn:Gimit_vs_dynT_CG_4,6,9M,20000T,100pond.png"
fig.savefig(filename, bbox_inches='tight')
